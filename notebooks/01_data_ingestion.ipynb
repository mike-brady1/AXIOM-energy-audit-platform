# %% [markdown]
# # AXIOM Data Ingestion Notebook
#
# Extract energy audit data from PDFs

# %%
import sys
sys.path.insert(0, '../src')

from ingestion.pdf_parser import parse_pdf

# Load and parse sample PDF
result = parse_pdf('../data/sample_bill.pdf')
print(result)
